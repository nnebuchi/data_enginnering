# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.2'

# %%
rf = pd.read_parquet('yellow_tripdata_2021-01.parquet')
rf.to_csv('yellow_tripdata_2021-01.csv')

# %%
pd.read_csv('yellow_tripdata_2021-01.csv', nrows=100)
# Out:
#     Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0            0         1  2021-01-01 00:30:10   2021-01-01 00:36:12
# 1            1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2            2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3            3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4            4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
# ..         ...       ...                  ...                   ...
# 95          95         2  2021-01-01 00:12:41   2021-01-01 00:26:47
# 96          96         2  2021-01-01 00:23:29   2021-01-01 00:35:03
# 97          97         2  2021-01-01 00:46:17   2021-01-01 00:54:25
# 98          98         2  2021-01-01 00:28:16   2021-01-01 00:51:44
# 99          99         2  2021-01-01 00:42:35   2021-01-01 00:54:41
#
#     passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0               1.0           2.10         1.0                  N
# ...

# %%
print(pd.io.sql.get_schema('yellow_taxi.csv', name='yellow_taxi-data'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(pd.io.sql.get_schema('yellow_taxi.csv', name='yellow_taxi-data'))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\sql.py:2255, in get_schema(frame, name, keys, con, dtype, schema)
#    2232 """
#    2233 Get the SQL db table schema for the given frame.
#    2234
#    (...)
#    2252     .. versionadded:: 1.2.0
#    2253 """
#    2254 pandas_sql = pandasSQL_builder(con=con)
# -> 2255 return pandas_sql._create_sql_schema(
#    2256     frame, name, keys=keys, dtype=dtype, schema=schema
#    2257 )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\sql.py:2212, in SQLiteDatabase._create_sql_schema(self, frame, table_name, keys, dtype, schema)
#    2204 def _create_sql_schema(
#    2205     self,
#    2206     frame,
#    (...)
# ...
